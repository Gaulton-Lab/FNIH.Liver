# %%
library(scran)
library(edgeR)
library(ggplot2)
library(tidyr)
library(dplyr)
library(NatParksPalettes)
library(stringr)
# Out:
# Warning message:
# “package ‘stringr’ was built under R version 4.3.2”

# %% [markdown]
# # CPM (TMM adjusted) normalization for H3K27ac - ATAC Peaks

# %%
unique_cell_types <- c('Endothelial', 'Hepatocytes', 'T', 'HSC', 'Cholangiocyte', 'Myeloid', 'NK', 'B', 'Mast', 'Schwann')

# %%
#looping through cell types by making ^ into a function
calculate_TMM <- function(cell.type, tmm.filename, pseudobulk.filename){
    x <- read.table(paste(pseudobulk.filename))
    
    if (sum(!colSums(x) != 0) > 0){
        print(paste0(cell.type, " has zero library size samples."))
        x <- x[,colSums(x) != 0]
    }
    
    edgeR.object <- DGEList(counts=x)
    edgeR.object <- calcNormFactors(object=edgeR.object, method='TMM')
    tmm.counts <- edgeR::cpm(edgeR.object, normalized.lib.sizes=T)

    #export df
    write.table(tmm.counts, tmm.filename, sep='\t',quote=FALSE)
}

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/ATAC.Peaks/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.TMM.ATAC.Peaks.tsv', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27ac_donor.LiverUnionPeaks.rpm.ct.peaks.tsv', sep = "")
    calculate_TMM(cell.type, tmm.filename, pseudobulk.filename)
}

# %% [markdown]
# # CPM (TMM adjusted) normalization for H3K27ac - TSS

# %%
unique_cell_types <- c('Endothelial', 'Hepatocytes', 'T', 'HSC', 'Cholangiocyte', 'Myeloid', 'NK', 'B', 'Mast', 'Schwann')

# %%
#looping through cell types by making ^ into a function
calculate_TMM <- function(cell.type, tmm.filename, pseudobulk.filename){
    x <- read.table(paste(pseudobulk.filename))
    
    if (sum(!colSums(x) != 0) > 0){
        print(paste0(cell.type, " has zero library size samples."))
        x <- x[,colSums(x) != 0]
    }
    
    edgeR.object <- DGEList(counts=x)
    edgeR.object <- calcNormFactors(object=edgeR.object, method='TMM')
    tmm.counts <- edgeR::cpm(edgeR.object, normalized.lib.sizes=T)

    #export df
    write.table(tmm.counts, tmm.filename, sep='\t',quote=FALSE)
}

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/TSS/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.TMM.TSS.tsv', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27ac_donor_count.xls', sep = "")
    calculate_TMM(cell.type, tmm.filename, pseudobulk.filename)
}

# %% [markdown]
# # CPM (TMM adjusted) normalization for H3K27me3 - ATAC Peaks

# %%
unique_cell_types <- c('Endothelial', 'Hepatocytes', 'T', 'HSC', 'Cholangiocyte', 'Myeloid', 'NK', 'B', 'Mast', 'Schwann')

# %%
#looping through cell types by making ^ into a function
calculate_TMM <- function(cell.type, tmm.filename, pseudobulk.filename){
    x <- read.table(paste(pseudobulk.filename))
    colnames(x) <- str_replace(colnames(x), paste0(cell.type, '\\.'), "")
    
    if (sum(!colSums(x) != 0) > 0){
        print(paste0(cell.type, " has zero library size samples."))
        x <- x[,colSums(x) != 0]
    }
    
    edgeR.object <- DGEList(counts=x)
    edgeR.object <- calcNormFactors(object=edgeR.object, method='TMM')
    tmm.counts <- edgeR::cpm(edgeR.object, normalized.lib.sizes=T)

    #export df
    write.table(tmm.counts, tmm.filename, sep='\t',quote=FALSE)
}

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/ATAC.Peaks/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.TMM.ATAC.Peaks.tsv', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27me3_donor.LiverUnionPeaks.rpm.ct.peaks.tsv', sep = "")
    calculate_TMM(cell.type, tmm.filename, pseudobulk.filename)
}

# %% [markdown]
# # CPM (TMM adjusted) normalization for H3K27me3 - TSS

# %%
unique_cell_types <- c('Endothelial', 'Hepatocytes', 'T', 'HSC', 'Cholangiocyte', 'Myeloid', 'NK', 'B', 'Mast', 'Schwann')

# %%
#looping through cell types by making ^ into a function
calculate_TMM <- function(cell.type, tmm.filename, pseudobulk.filename){
    x <- read.table(paste(pseudobulk.filename))
    
    if (sum(!colSums(x) != 0) > 0){
        print(paste0(cell.type, " has zero library size samples."))
        x <- x[,colSums(x) != 0]
    }
    
    edgeR.object <- DGEList(counts=x)
    edgeR.object <- calcNormFactors(object=edgeR.object, method='TMM')
    tmm.counts <- edgeR::cpm(edgeR.object, normalized.lib.sizes=T)

    #export df
    write.table(tmm.counts, tmm.filename, sep='\t',quote=FALSE)
}

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/TSS/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.TMM.TSS.tsv', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27me3_donor_count.xls', sep = "")
    calculate_TMM(cell.type, tmm.filename, pseudobulk.filename)
}

# %% [markdown]
# # CPM (Not TMM)

# %%
#looping through cell types by making ^ into a function
calculate_CPM <- function(cell.type, cpm.filename, pseudobulk.filename){
    x <- read.table(paste(pseudobulk.filename))
    
    cpm <- x
    for (i in 1:ncol(x)){
        cpm[,i] <- 1e6 * (x[,i]/sum(x[,i]))
    }
    
    #export df
    write.table(cpm, cpm.filename, sep='\t',quote=FALSE)
}

# %% [markdown]
# ##  CPM - H3K27ac ATAC Peaks

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'

##### NAME YOUR FILES #####
for (cell.type in c(unique_cell_types)){
    cpm.filename <- paste(outdir, cell.type, '_H3K27ac_donor.LiverUnionPeaks.cpm.ct.peaks.tsv', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27ac_donor.LiverUnionPeaks.rpm.ct.peaks.tsv', sep = "")
    calculate_CPM(cell.type, cpm.filename, pseudobulk.filename)
}

# %% [markdown]
# ##  CPM - H3K27ac TSS

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'

##### NAME YOUR FILES #####
for (cell.type in c(unique_cell_types)){
    cpm.filename <- paste(outdir, cell.type, '_H3K27ac_donor_count.CPM.xls', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27ac_donor_count.xls', sep = "")
    calculate_CPM(cell.type, cpm.filename, pseudobulk.filename)
}

# %% [markdown]
# ##  CPM - H3K27me3 ATAC Peaks

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'

##### NAME YOUR FILES #####
for (cell.type in c(unique_cell_types)){
    cpm.filename <- paste(outdir, cell.type, '_H3K27me3_donor.LiverUnionPeaks.cpm.ct.peaks.tsv', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27me3_donor.LiverUnionPeaks.rpm.ct.peaks.tsv', sep = "")
    calculate_CPM(cell.type, cpm.filename, pseudobulk.filename)
}

# %% [markdown]
# ##  CPM - H3K27me3 TSS

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'

##### NAME YOUR FILES #####
for (cell.type in c(unique_cell_types)){
    cpm.filename <- paste(outdir, cell.type, '_H3K27me3_donor_count.CPM.xls', sep = "")
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27me3_donor_count.xls', sep = "")
    calculate_CPM(cell.type, cpm.filename, pseudobulk.filename)
}

# %% [markdown]
# # INT sources
# https://www.nature.com/articles/nature11401#Sec4
# https://www.biostars.org/p/80597/

# %%
rankNormal <- function(x) {
    return(qnorm((rank(x,na.last="keep")-0.5)/sum(!is.na(x))))
}

INTransform <- function(cell.type, tmm.filename, pseudobulk.filename, tpm.filename, 
                        int.filename, TPM.cut=.1, count.cut=6) {
    tmm.data <- suppressWarnings(tibble::column_to_rownames(data.table::fread(tmm.filename),var='V1'))
    tpm.data <- suppressWarnings(tibble::column_to_rownames(data.table::fread(tpm.filename),var='V1'))
    pseudobulk.data <- suppressWarnings(tibble::column_to_rownames(data.table::fread(pseudobulk.filename),var='V1'))
    
    tpm.data <- tpm.data[colnames(tmm.data)]
    pseudobulk.data <- pseudobulk.data[colnames(tmm.data)]
    
    print(paste0('Processing ', cell.type))
    features <- rownames(tpm.data)[(rowSums(pseudobulk.data >= count.cut) >= (ncol(pseudobulk.data) * .2)) & 
                                   (rowSums(tpm.data >= TPM.cut) >= (ncol(tpm.data) * .2))]
    print(paste0("Features after TPM cutoff of ", TPM.cut, " for 20% of samples: ", 
                 sum((rowSums(tpm.data >= TPM.cut) >= (ncol(tpm.data) * .2)))))
    print(paste0("Features after count cutoff of ", count.cut, " for 20% of samples: ", 
                 sum((rowSums(pseudobulk.data >= count.cut) >= (ncol(pseudobulk.data) * .2)))))
    print(paste0("Features after both filters: ", length(features)))
    
    tmm.data.filt <- tmm.data[features,]
    
    int.data <- t(apply(tmm.data.filt, 1, rankNormal))
    write.table(int.data, int.filename, sep='\t', quote=F, row.names=T, col.names=T)
}

# %% [markdown]
# ## H3K27ac ATAC

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/ATAC.Peaks/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27ac_donor.LiverUnionPeaks.rpm.ct.peaks.tsv', sep = "")
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.TMM.ATAC.Peaks.tsv', sep = "")
    tpm.filename <- paste(indir, cell.type, '_H3K27ac_donor.LiverUnionPeaks.cpm.ct.peaks.tsv', sep = "")
    int.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.INT.ATAC.Peaks.tsv', sep = "")
    INTransform(cell.type, tmm.filename, pseudobulk.filename, tpm.filename, int.filename, TPM.cut=.1, count.cut=6)
}
# Out:
# [1] "Processing Endothelial"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 140411"
# [1] "Features after count cutoff of 6 for 20% of samples: 14554"
# [1] "Features after both filters: 14554"
# [1] "Processing Hepatocytes"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 293809"
# [1] "Features after count cutoff of 6 for 20% of samples: 69879"
# [1] "Features after both filters: 69879"
# [1] "Processing T"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 33899"
# [1] "Features after count cutoff of 6 for 20% of samples: 19"
# [1] "Features after both filters: 19"
# [1] "Processing HSC"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 93200"
# [1] "Features after count cutoff of 6 for 20% of samples: 227"
# [1] "Features after both filters: 227"
# [1] "Processing Cholangiocyte"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 96559"
# [1] "Features after count cutoff of 6 for 20% of samples: 3585"
# ...

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/TSS/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27ac_donor_count.xls', sep = "")
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.TMM.TSS.tsv', sep = "")
    tpm.filename <- paste(indir, cell.type, '_H3K27ac_donor_count.CPM.xls', sep = "")
    int.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.INT.TSS.tsv', sep = "")
    INTransform(cell.type, tmm.filename, pseudobulk.filename, tpm.filename, int.filename, TPM.cut=.1, count.cut=6)
}
# Out:
# [1] "Processing Endothelial"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 53077"
# [1] "Features after count cutoff of 6 for 20% of samples: 32519"
# [1] "Features after both filters: 32519"
# [1] "Processing Hepatocytes"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 63567"
# [1] "Features after count cutoff of 6 for 20% of samples: 40308"
# [1] "Features after both filters: 40308"
# [1] "Processing T"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 36295"
# [1] "Features after count cutoff of 6 for 20% of samples: 693"
# [1] "Features after both filters: 693"
# [1] "Processing HSC"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 46698"
# [1] "Features after count cutoff of 6 for 20% of samples: 8419"
# [1] "Features after both filters: 8419"
# [1] "Processing Cholangiocyte"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 47167"
# [1] "Features after count cutoff of 6 for 20% of samples: 20153"
# ...

# %%
rankNormal <- function(x) {
    return(qnorm((rank(x,na.last="keep")-0.5)/sum(!is.na(x))))
}

INTransform.ATAC.me3 <- function(cell.type, tmm.filename, pseudobulk.filename, tpm.filename, 
                        int.filename, TPM.cut=.1, count.cut=6) {
    tmm.data <- suppressWarnings(tibble::column_to_rownames(data.table::fread(tmm.filename),var='V1'))
    tpm.data <- suppressWarnings(tibble::column_to_rownames(data.table::fread(tpm.filename),var='V1'))
    colnames(tpm.data) <- str_replace(colnames(tpm.data), paste0(cell.type, '\\.'), "")
    pseudobulk.data <- suppressWarnings(tibble::column_to_rownames(data.table::fread(pseudobulk.filename),var='V1'))
    colnames(pseudobulk.data) <- str_replace(colnames(pseudobulk.data), paste0(cell.type, '\\.'), "")
    
    tpm.data <- tpm.data[colnames(tmm.data)]
    pseudobulk.data <- pseudobulk.data[colnames(tmm.data)]
    
    print(paste0('Processing ', cell.type))
    features <- rownames(tpm.data)[(rowSums(pseudobulk.data >= count.cut) >= (ncol(pseudobulk.data) * .2)) & 
                                   (rowSums(tpm.data >= TPM.cut) >= (ncol(tpm.data) * .2))]
    print(paste0("Features after TPM cutoff of ", TPM.cut, " for 20% of samples: ", 
                 sum((rowSums(tpm.data >= TPM.cut) >= (ncol(tpm.data) * .2)))))
    print(paste0("Features after count cutoff of ", count.cut, " for 20% of samples: ", 
                 sum((rowSums(pseudobulk.data >= count.cut) >= (ncol(pseudobulk.data) * .2)))))
    print(paste0("Features after both filters: ", length(features)))
    
    tmm.data.filt <- tmm.data[features,]
    
    int.data <- t(apply(tmm.data.filt, 1, rankNormal))
    write.table(int.data, int.filename, sep='\t', quote=F, row.names=T, col.names=T)
}

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/LiverUnionPeak_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/ATAC.Peaks/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27me3_donor.LiverUnionPeaks.rpm.ct.peaks.tsv', sep = "")
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.TMM.ATAC.Peaks.tsv', sep = "")
    tpm.filename <- paste(indir, cell.type, '_H3K27me3_donor.LiverUnionPeaks.cpm.ct.peaks.tsv', sep = "")
    int.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.INT.ATAC.Peaks.tsv', sep = "")
    INTransform.ATAC.me3(cell.type, tmm.filename, pseudobulk.filename, tpm.filename, int.filename, TPM.cut=.1, count.cut=6)
}
# Out:
# [1] "Processing Endothelial"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 36732"
# [1] "Features after count cutoff of 6 for 20% of samples: 206"
# [1] "Features after both filters: 206"
# [1] "Processing Hepatocytes"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 161340"
# [1] "Features after count cutoff of 6 for 20% of samples: 34614"
# [1] "Features after both filters: 34614"
# [1] "Processing T"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 10857"
# [1] "Features after count cutoff of 6 for 20% of samples: 3"
# [1] "Features after both filters: 3"
# [1] "Processing HSC"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 16252"
# [1] "Features after count cutoff of 6 for 20% of samples: 4"
# [1] "Features after both filters: 4"
# [1] "Processing Cholangiocyte"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 21707"
# [1] "Features after count cutoff of 6 for 20% of samples: 99"
# [1] "Features after both filters: 99"
# ...

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/DPT.files/tss_mtx/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/TSS/counts/'

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    pseudobulk.filename <- paste(indir, cell.type, '_H3K27me3_donor_count.xls', sep = "")
    tmm.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.TMM.TSS.tsv', sep = "")
    tpm.filename <- paste(indir, cell.type, '_H3K27me3_donor_count.CPM.xls', sep = "")
    int.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.INT.TSS.tsv', sep = "")
    INTransform(cell.type, tmm.filename, pseudobulk.filename, tpm.filename, int.filename, TPM.cut=.1, count.cut=6)
}
# Out:
# [1] "Processing Endothelial"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 38116"
# [1] "Features after count cutoff of 6 for 20% of samples: 2535"
# [1] "Features after both filters: 2535"
# [1] "Processing Hepatocytes"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 71248"
# [1] "Features after count cutoff of 6 for 20% of samples: 24578"
# [1] "Features after both filters: 24578"
# [1] "Processing T"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 22924"
# [1] "Features after count cutoff of 6 for 20% of samples: 2"
# [1] "Features after both filters: 2"
# [1] "Processing HSC"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 18320"
# [1] "Features after count cutoff of 6 for 20% of samples: 21"
# [1] "Features after both filters: 21"
# [1] "Processing Cholangiocyte"
# [1] "Features after TPM cutoff of 0.1 for 20% of samples: 27219"
# [1] "Features after count cutoff of 6 for 20% of samples: 1434"
# ...

# %% [raw]
# GTEX does PEERs factors on normalized data
#
# From GTEX (https://github.com/broadinstitute/gtex-pipeline/blob/master/qtl/README.md):
# The number of PEER factors was selected as function of sample size (N):
#
# 15 factors for N < 150
# 30 factors for 150 ≤ N < 250
# 45 factors for 250 ≤ N < 350
# 60 factors for N ≥ 350
#
# Based on this paper PCA should be sufficient: https://genomebiology.biomedcentral.com/articles/10.1186/s13059-021-02407-x#Abs1
# This paper agrees: https://genomebiology.biomedcentral.com/articles/10.1186/s13059-022-02761-4

# %%
make_PC_covariate_mat <- function(cell.type, expr.mat.filename, pc.filename, cor.filename, n_pc=15, meta) {
    test.data <- read.table(expr.mat.filename)
    pca.res <- prcomp(t(test.data))
    
    print(paste0(n_pc, " PCs cover ", summary(pca.res)$importance[3,15] * 100, "% of variance for ", cell.type))
    
    # Check for outliers
    for (i in 1:n_pc) {
        if(sum(abs(pca.res$x[,i]) > pca.res$sdev[i] * 3) != 0) {
            print(paste0(names(which(abs(pca.res$x[,i]) > pca.res$sdev[i] * 3)), 
                 ' is an outlier on PC', i, " for ", cell.type))
        }
    }
    
    write.table(pca.res$x[,1:15], pc.filename,
               sep='\t', col.names=T, row.names=T, quote=F)
    
    # Correlate with metadata
    cor.res <- cor(cbind(pca.res$x[,1:15], meta[rownames(pca.res$x),]))[1:15,16:(15 + ncol(meta))]
    cor.plot.data <- tidyr::pivot_longer(tibble::rownames_to_column(data.frame(cor.res), var='PC'), 
                        names_to = 'Covariate', values_to = 'Coefficient', cols = -PC)
    write.table(cor.plot.data, cor.filename,
               sep='\t', col.names=T, row.names=T, quote=F)
    
    # Plot correlation
    p1 <- ggplot(cor.plot.data, aes(x=PC, y=Covariate, fill=Coefficient)) + geom_tile() + 
        scale_fill_gradientn(colors=natparks.pals("Olympic"), limits=c(-1,1)) + 
        theme_classic(base_size=16) + ggtitle(cell.type)
    print(p1)
}

# %%
options(repr.plot.width=12, repr.plot.height=8)

# %%
meta = read.table("/nfs/lab/projects/nash_nafld_liver/downstream_all/08_H3K27ac_DESEQ/H3K27ac.meta.tsv", 
                  sep='\t', header=T)
#colnames(meta)
meta <- tibble::column_to_rownames(meta, var='donor_demux')
meta$Gender <- as.integer(factor(meta$Gender))
meta$disease_status <- as.integer(factor(meta$disease_status))
meta$batch <- as.integer(factor(meta$batch))
meta$condition <- as.integer(factor(meta$condition, levels=c('Control','MASL','MASH','MetALD')))
meta <- dplyr::select(meta, -Ballooning, -Fat.distribution, -Hepatocyte.necrosis, -Portal.inflammation,
                     -Age, -BMI)

dim(meta)
head(meta)
# Out:
# [1] 86 18
#          B  Cholangiocyte Endothelial Hepatocytes HSC Mast Myeloid NK Schwann
# HL150001 12  17            58          534         15 1     78     10 0
# HL150009  3  11           104          761        116 0     65     17 3
# HL150013 22  37           112          281         77 4    100     20 0
# HL150015 12  69            89         1266         66 0     59     15 0
# HL160017 10  32            71         1476         26 0    234     10 1
# HL160022  0 129            45          131         28 0     50      0 2
#          T  batch disease_status condition Steatosis.grade Fibrosis.stage
# HL150001  4 1     2              2         1               0
# HL150009 10 1     2              2         1               0
# HL150013 31 3     2              3         1               2
# HL150015 22 1     2              2         3               1
# HL160017 22 1     2              4         1               2
# HL160022  7 3     2              3         3               2
# ...

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/ATAC.Peaks/counts/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/ATAC.Peaks/covariates/'

n_pc <- 15

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    # Not enough stuff for these cell types
    if (cell.type %in% c('NK','Mast','Schwann','B')) {
        next
    }
    #tmm.filename <- paste(indir, cell.type, '_perdonor.H3K27ac.TMM.tsv', sep = "")
    int.filename <- paste(indir, cell.type, '_perdonor.H3K27ac.INT.ATAC.Peaks.tsv', sep = "")
    pc.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.INT.ATAC.Peaks.', n_pc,'.PCs.tsv', sep = "")
    cor.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.INT.ATAC.Peaks.', n_pc,'.PCs.correlation.tsv', sep = "")
    make_PC_covariate_mat(cell.type, expr.mat.filename=int.filename, pc.filename, 
                          cor.filename, n_pc=15, meta)
}
# Out:
# [1] "15 PCs cover 37.26% of variance for Endothelial"
# [1] "HL190827 is an outlier on PC5 for Endothelial"
# [1] "HL190827 is an outlier on PC6 for Endothelial"
# [2] "HL221006 is an outlier on PC6 for Endothelial"
# [1] "HL200615 is an outlier on PC7 for Endothelial"
# [2] "HL210727 is an outlier on PC7 for Endothelial"
# [3] "HL221006 is an outlier on PC7 for Endothelial"
# [1] "HL170055 is an outlier on PC8 for Endothelial"
# [2] "HL190827 is an outlier on PC8 for Endothelial"
# [3] "HL210727 is an outlier on PC8 for Endothelial"
# [1] "HL170055 is an outlier on PC9 for Endothelial"
# [2] "HL210727 is an outlier on PC9 for Endothelial"
# [3] "HL230212 is an outlier on PC9 for Endothelial"
# [1] "HL160017 is an outlier on PC10 for Endothelial"
# [2] "HL200615 is an outlier on PC10 for Endothelial"
# [3] "HL210806 is an outlier on PC10 for Endothelial"
# [1] "HL170048 is an outlier on PC11 for Endothelial"
# [2] "HL170055 is an outlier on PC11 for Endothelial"
# ...

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/ATAC.Peaks/counts/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/ATAC.Peaks/covariates/'

n_pc <- 15

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    # Not enough stuff for these cell types
    if (cell.type %in% c('Mast','Schwann','T','NK','B','HSC')) {
        next
    }
    #tmm.filename <- paste(indir, cell.type, '_perdonor.H3K27me3.TMM.tsv', sep = "")
    int.filename <- paste(indir, cell.type, '_perdonor.H3K27me3.INT.ATAC.Peaks.tsv', sep = "")
    pc.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.INT.ATAC.Peaks.', n_pc,'.PCs.tsv', sep = "")
    cor.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.INT.ATAC.Peaks.', n_pc,'.PCs.correlation.tsv', sep = "")
    make_PC_covariate_mat(cell.type, expr.mat.filename=int.filename, pc.filename, 
                          cor.filename, n_pc=15, meta)
}
# Out:
# [1] "15 PCs cover 55.597% of variance for Endothelial"
# [1] "HL210207 is an outlier on PC2 for Endothelial"
# [1] "HL190909 is an outlier on PC12 for Endothelial"
# [1] "HL190624 is an outlier on PC14 for Endothelial"
# [1] "15 PCs cover 41.891% of variance for Hepatocytes"
# [1] "HL160026 is an outlier on PC2 for Hepatocytes"
# [2] "HL181031 is an outlier on PC2 for Hepatocytes"
# [1] "HL180071 is an outlier on PC4 for Hepatocytes"
# [1] "HL210207 is an outlier on PC5 for Hepatocytes"
# [1] "HL160035 is an outlier on PC6 for Hepatocytes"
# [2] "HL210207 is an outlier on PC6 for Hepatocytes"
# [1] "HL160035 is an outlier on PC7 for Hepatocytes"
# [2] "HL210207 is an outlier on PC7 for Hepatocytes"
# [1] "HL190214 is an outlier on PC8 for Hepatocytes"
# [1] "HL160022 is an outlier on PC9 for Hepatocytes"
# [2] "HL160035 is an outlier on PC9 for Hepatocytes"
# [3] "HL201024 is an outlier on PC9 for Hepatocytes"
# [1] "HL160022 is an outlier on PC10 for Hepatocytes"
# ...

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/TSS/counts/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/06_H3K27acQTLs/TSS/covariates/'

n_pc <- 15

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    # Not enough stuff for these cell types
    if (cell.type %in% c('Mast','Schwann')) {
        next
    }
    #tmm.filename <- paste(indir, cell.type, '_perdonor.H3K27ac.TMM.tsv', sep = "")
    int.filename <- paste(indir, cell.type, '_perdonor.H3K27ac.INT.TSS.tsv', sep = "")
    pc.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.INT.TSS.', n_pc,'.PCs.tsv', sep = "")
    cor.filename <- paste(outdir, cell.type, '_perdonor.H3K27ac.INT.TSS.', n_pc,'.PCs.correlation.tsv', sep = "")
    make_PC_covariate_mat(cell.type, expr.mat.filename=int.filename, pc.filename, 
                          cor.filename, n_pc=15, meta)
}
# Out:
# [1] "15 PCs cover 32.524% of variance for Endothelial"
# [1] "HL160022 is an outlier on PC1 for Endothelial"
# [2] "HL181029 is an outlier on PC1 for Endothelial"
# [1] "HL160022 is an outlier on PC3 for Endothelial"
# [2] "HL170055 is an outlier on PC3 for Endothelial"
# [3] "HL230212 is an outlier on PC3 for Endothelial"
# [1] "HL160022 is an outlier on PC4 for Endothelial"
# [2] "HL181029 is an outlier on PC4 for Endothelial"
# [1] "HL210727 is an outlier on PC5 for Endothelial"
# [2] "HL210806 is an outlier on PC5 for Endothelial"
# [1] "HL160022 is an outlier on PC6 for Endothelial"
# [2] "HL181029 is an outlier on PC6 for Endothelial"
# [3] "HL190827 is an outlier on PC6 for Endothelial"
# [4] "HL210806 is an outlier on PC6 for Endothelial"
# [1] "HL170055 is an outlier on PC7 for Endothelial"
# [2] "HL230212 is an outlier on PC7 for Endothelial"
# [1] "HL150001 is an outlier on PC8 for Endothelial"
# [2] "HL190827 is an outlier on PC8 for Endothelial"
# ...

# %%
indir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/TSS/counts/'
outdir <- '/nfs/lab/tscc/welison/FNIH.Liver/tensorQTL/07_H3K27me3QTLs/TSS/covariates/'

n_pc <- 15

##### NAME YOUR FILES #####
for (cell.type in unique_cell_types){
    # Not enough stuff for these cell types
    if (cell.type %in% c('NK','B','Mast','Schwann','T')) {
        next
    }
    #tmm.filename <- paste(indir, cell.type, '_perdonor.H3K27me3.TMM.tsv', sep = "")
    int.filename <- paste(indir, cell.type, '_perdonor.H3K27me3.INT.TSS.tsv', sep = "")
    pc.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.INT.TSS.', n_pc,'.PCs.tsv', sep = "")
    cor.filename <- paste(outdir, cell.type, '_perdonor.H3K27me3.INT.TSS.', n_pc,'.PCs.correlation.tsv', sep = "")
    make_PC_covariate_mat(cell.type, expr.mat.filename=int.filename, pc.filename, 
                          cor.filename, n_pc=15, meta)
}
# Out:
# [1] "15 PCs cover 43.057% of variance for Endothelial"
# [1] "HL160022 is an outlier on PC1 for Endothelial"
# [1] "HL200707 is an outlier on PC2 for Endothelial"
# [1] "HL150009 is an outlier on PC3 for Endothelial"
# [1] "HL170047 is an outlier on PC4 for Endothelial"
# [1] "HL170055 is an outlier on PC6 for Endothelial"
# [1] "HL191002 is an outlier on PC8 for Endothelial"
# [1] "HL200805 is an outlier on PC9 for Endothelial"
# [2] "HL210727 is an outlier on PC9 for Endothelial"
# [1] "HL230212 is an outlier on PC12 for Endothelial"
# [1] "HL191216 is an outlier on PC13 for Endothelial"
# [1] "15 PCs cover 45.109% of variance for Hepatocytes"
# [1] "HL160026 is an outlier on PC2 for Hepatocytes"
# [1] "HL190214 is an outlier on PC6 for Hepatocytes"
# [2] "HL220825 is an outlier on PC6 for Hepatocytes"
# [1] "HL190606 is an outlier on PC7 for Hepatocytes"
# [2] "HL210614 is an outlier on PC7 for Hepatocytes"
# [3] "HL211106 is an outlier on PC7 for Hepatocytes"
# ...
